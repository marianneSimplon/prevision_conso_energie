# %% [markdown]
# **Context:**
#
# Measurements of electric power consumption in one household with a one-minute sampling rate over a period of almost 4 years. Different electrical quantities and some sub-metering values are available.
#
# This archive contains 2075259 measurements gathered between December 2006 and November 2010 (47 months).
#
# **Notes:**
#
# 1. (globalactivepower*1000/60 - submetering1 - submetering2 - submetering3) represents the active energy consumed every minute (in watt hour) in the household by electrical equipment not measured in sub-meterings 1, 2 and 3.
#
# 2. The dataset contains some missing values in the measurements (nearly 1,25% of the rows). All calendar timestamps are present in the dataset but for some timestamps, the measurement values are missing: a missing value is represented by the absence of value between two consecutive semi-colon attribute separators. For instance, the dataset shows missing values on April 28, 2007.
#
# **Attribute Information:**
#
# 1. **date :** Date in format dd/mm/yyyy
#
# 2. **time :** time in format hh:mm:ss
#
# 3. **globalactivepower :** household global minute-averaged active power (in kilowatt)
#
# 4. **globalreactivepower :** household global minute-averaged reactive power (in kilowatt)
#
# 5. **voltage :** minute-averaged voltage (in volt)
#
# 6. **global_intensity :** household global minute-averaged current intensity (in ampere)
#
# 7. **submetering1 :** energy sub-metering No. 1 (in watt-hour of active energy). It corresponds to the kitchen, containing mainly a dishwasher, an oven and a microwave (hot plates are not electric but gas powered).
#
# 8. **submetering2 :** energy sub-metering No. 2 (in watt-hour of active energy). It corresponds to the laundry room, containing a washing-machine, a tumble-drier, a refrigerator and a light.
#
# 9. **submetering3 :** energy sub-metering No. 3 (in watt-hour of active energy). It corresponds to an electric water-heater and an air-conditioner.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', 100)

# %%
na_values = "", "#N/A", "#N/A N/A", "#NA", "-1.#IND", "-1.#QNAN", "-NaN", "-nan", "1.#IND", "1.#QNAN", "<NA>", "N/A", "NA", "NULL", "NaN", "n/a", "nan", "null" , "?"
df = pd.read_csv('../data_projet1/household_power_consumption.txt', delimiter=";", na_values=na_values)

# %%
df["DateTime"] = df["Date"] +" "+ df["Time"]

# %%
df.Date = pd.to_datetime(df.Date, format="%d/%m/%Y")
df.DateTime = pd.to_datetime(df.DateTime,format="%d/%m/%Y %H:%M:%S")
df.Time = pd.to_datetime(df.Time, format="%H:%M:%S").dt.time

# %%
df.head()
# Out:
#         Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0 2006-12-16  17:24:00                4.216                  0.418   234.84
# 1 2006-12-16  17:25:00                5.360                  0.436   233.63
# 2 2006-12-16  17:26:00                5.374                  0.498   233.29
# 3 2006-12-16  17:27:00                5.388                  0.502   233.74
# 4 2006-12-16  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0
#
#              DateTime
# 0 2006-12-16 17:24:00
# 1 2006-12-16 17:25:00
# 2 2006-12-16 17:26:00
# 3 2006-12-16 17:27:00
# 4 2006-12-16 17:28:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 10 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   datetime64[ns]
#  1   Time                   object
#  2   Global_active_power    float64
#  3   Global_reactive_power  float64
#  4   Voltage                float64
#  5   Global_intensity       float64
#  6   Sub_metering_1         float64
#  7   Sub_metering_2         float64
#  8   Sub_metering_3         float64
#  9   DateTime               datetime64[ns]
# dtypes: datetime64[ns](2), float64(7), object(1)
# memory usage: 158.3+ MB

# %%
df.describe()
# Out:
#        Global_active_power  Global_reactive_power       Voltage  \
# count         2.049280e+06           2.049280e+06  2.049280e+06
# mean          1.091615e+00           1.237145e-01  2.408399e+02
# std           1.057294e+00           1.127220e-01  3.239987e+00
# min           7.600000e-02           0.000000e+00  2.232000e+02
# 25%           3.080000e-01           4.800000e-02  2.389900e+02
# 50%           6.020000e-01           1.000000e-01  2.410100e+02
# 75%           1.528000e+00           1.940000e-01  2.428900e+02
# max           1.112200e+01           1.390000e+00  2.541500e+02
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count      2.049280e+06    2.049280e+06    2.049280e+06    2.049280e+06
# mean       4.627759e+00    1.121923e+00    1.298520e+00    6.458447e+00
# std        4.444396e+00    6.153031e+00    5.822026e+00    8.437154e+00
# min        2.000000e-01    0.000000e+00    0.000000e+00    0.000000e+00
# 25%        1.400000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 50%        2.600000e+00    0.000000e+00    0.000000e+00    1.000000e+00
# 75%        6.400000e+00    0.000000e+00    1.000000e+00    1.700000e+01
# max        4.840000e+01    8.800000e+01    8.000000e+01    3.100000e+01

# %%
df.duplicated().value_counts()
# Out:
# False    2075259
# dtype: int64

# %%
df.isna().sum()
# Out:
# Date                         0
# Time                         0
# Global_active_power      25979
# Global_reactive_power    25979
# Voltage                  25979
# Global_intensity         25979
# Sub_metering_1           25979
# Sub_metering_2           25979
# Sub_metering_3           25979
# DateTime                     0
# dtype: int64

# %%
from datetime import date, timedelta

# %%
# mes_dates = df.Date.to_period("D")

mes_dates = pd.Series(df.Date.unique()).sort_values()
start_date = mes_dates[0]
end_date = mes_dates[len(mes_dates)-1]
numdays = (end_date - start_date).days

mes_dates = list(mes_dates)

all_dates = []

for x in range (0, (numdays+1)):
    all_dates.append(start_date + timedelta(days = x))

dates_missing = []

for i in range(0, len(all_dates)):
   if (all_dates[i] not in mes_dates):
       dates_missing.append(all_dates[i])
   else:
       pass
    
print(str(start_date)+" à "+str(end_date))
pd.DataFrame(dates_missing)
# Out:
# 2006-12-16 00:00:00 à 2010-11-26 00:00:00
# Empty DataFrame
# Columns: []
# Index: []

# %%
sns.countplot(x=df.Global_intensity, data=df)
# Out:
# <AxesSubplot:xlabel='Global_intensity', ylabel='count'>

# %%
# pd.DataFrame(df).plot()

# %%
df[df['Date']=="2010-02-09"].nunique()
# Out:
# Date                        1
# Time                     1440
# Global_active_power       654
# Global_reactive_power     149
# Voltage                   785
# Global_intensity           92
# Sub_metering_1             10
# Sub_metering_2              3
# Sub_metering_3             17
# DateTime                 1440
# dtype: int64

# %%
pd.DataFrame(df[df.Global_intensity.isna()==True]['Date'].value_counts()) 
# 1 jour = 1440 données
# Out:
#             Date
# 2010-08-20  1440
# 2010-08-18  1440
# 2010-08-21  1440
# 2007-04-29  1440
# 2010-01-13  1440
# 2010-08-19  1440
# 2010-09-26  1440
# 2010-09-27  1440
# 2009-06-14  1440
# 2007-04-28  1419
# 2009-06-13  1410
# 2010-08-22  1288
# 2010-03-20  1208
# 2010-09-25  1204
# 2010-09-28  1153
# 2010-01-14  1142
# 2009-08-13   891
# 2007-04-30   864
# 2010-03-21   819
# 2010-01-12   547
# 2009-06-15   455
# 2010-08-17   178
# 2007-07-15   130
# 2008-12-10    70
# 2008-10-25    43
# 2007-06-09    38
# 2009-02-01    38
# 2009-02-17    24
# 2007-08-01    21
# 2008-11-10     6
# 2009-07-10     4
# 2009-05-26     3
# 2009-02-14     2
# 2009-04-13     2
# 2009-12-10     2
# 2007-02-22     2
# 2007-09-26     2
# 2008-02-23     2
# 2008-05-16     2
# 2006-12-30     2
# 2006-12-21     2
# 2007-10-23     2
# 2008-07-13     2
# 2008-11-12     2
# 2007-06-19     2
# 2009-09-30     2
# 2010-02-14     1
# 2010-05-13     1
# 2010-01-02     1
# 2007-06-29     1
# 2007-03-25     1
# 2009-05-10     1
# 2007-01-14     1
# 2008-01-13     1
# 2007-07-22     1
# 2008-02-02     1
# 2008-12-20     1
# 2007-11-29     1
# 2007-06-06     1
# 2007-08-24     1
# 2009-03-16     1
# 2010-04-11     1
# 2008-11-23     1
# 2008-06-13     1
# 2009-01-14     1
# 2010-06-29     1
# 2008-08-31     1
# 2007-06-01     1
# 2008-08-04     1
# 2007-12-17     1
# 2007-11-21     1
# 2007-01-28     1
# 2010-10-24     1
# 2010-07-15     1
# 2009-10-11     1
# 2010-02-10     1
# 2009-09-13     1
# 2010-01-23     1
# 2009-03-01     1
# 2010-06-12     1
# 2008-03-24     1
# 2009-11-09     1

# %%
df.plot(kind='box', subplots=True, layout=(3, 4), figsize = (16, 14));

# %%
# sns.pairplot(data=df)

# %%
# plt.subplots(figsize=(16,5))
# sns.countplot(x=df.Global_intensity, data=df)
# plt.show()

# %%
# plt.subplots(figsize=(16,5))
# sns.countplot(x=df.Global_active_power, data=df)
# plt.show()

# %%
# plt.subplots(figsize=(16,5))
# sns.countplot(x=df.Global_reactive_power, data=df)
# plt.show()

# %%
# plt.subplots(figsize=(16,5))
# sns.countplot(x=df.Voltage, data=df)
# plt.show()

# %%
# plt.subplots(figsize=(16,5))
# sns.countplot(x=df.Sub_metering_1, data=df)
# plt.show()

# %%
# plt.subplots(figsize=(16,5))
# sns.countplot(x=df.Sub_metering_2, data=df)
# plt.show()

# %%
# plt.subplots(figsize=(16,5))
# sns.countplot(x=df.Sub_metering_3, data=df)
# plt.show()

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col1 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col2 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col4 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col5 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col6 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow1_col0 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow1_col2 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow1_col3 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow1_col4 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow1_col5 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow1_col6 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow3_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow3_col1 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow3_col4 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow3_col5 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow3_col6 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow4_col0 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow4_col1 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow4_col2 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow4_col3 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow4_col5 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow4_col6 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow5_col0 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow5_col1 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow5_col2 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow5_col3 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow5_col4 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow5_col6 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow6_col0 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow6_col1 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow6_col2 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow6_col3 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow6_col4 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow6_col5 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_54ad6091_6e3e_11ec_bfea_5ce0c527341c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Global_active_power</th>        <th class="col_heading level0 col1" >Global_reactive_power</th>        <th class="col_heading level0 col2" >Voltage</th>        <th class="col_heading level0 col3" >Global_intensity</th>        <th class="col_heading level0 col4" >Sub_metering_1</th>        <th class="col_heading level0 col5" >Sub_metering_2</th>        <th class="col_heading level0 col6" >Sub_metering_3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_54ad6091_6e3e_11ec_bfea_5ce0c527341clevel0_row0" class="row_heading level0 row0" >Global_active_power</th>
#                         <td id="T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col1" class="data row0 col1" >0.247017</td>
#                         <td id="T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col2" class="data row0 col2" >-0.399762</td>
#                         <td id="T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col3" class="data row0 col3" >0.998889</td>
#                         <td id="T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col4" class="data row0 col4" >0.484401</td>
#                         <td id="T_54ad6091_6e3e_11ec_bfea_5ce0c527341crow0_col5" class="data row0 col5" >

# %% [markdown]
# # EDA pour Time Series

# %%
df_day = df.groupby(by=["Time"]).mean()
df_day.Global_active_power.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
df_date = df.copy()

# %%
df_date = df_date.set_index('DateTime')

# %%
# plot target by day
f, ax1 = plt.subplots(1,1,figsize=(15,5))
dayly = df_date['Global_active_power'].resample('D').mean()
dayly.plot(style=[':', '--', '-'])
plt.ylabel('Global_active_power per day');

# %%
# plot target by month
f, ax1 = plt.subplots(1,1,figsize=(15,5))
monthly = df_date['Global_active_power'].resample('D').sum()
monthly.plot(style=[':', '--', '-'])
plt.ylabel('Global_active_power per month');

# %%
df_date['2006-12-16'][::1].sum()
# Out:
# Global_active_power       1209.176
# Global_reactive_power       34.922
# Voltage                  93552.530
# Global_intensity          5180.800
# Sub_metering_1               0.000
# Sub_metering_2             546.000
# Sub_metering_3            4926.000
# dtype: float64

# %%
from pandas import read_csv
from matplotlib import pyplot
# load dataset
# dataset = read_csv('pollution.csv', header=0, index_col=0)
values = df_date.values
# specify columns to plot
groups = [3,4,5,6]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(df_date.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %%
raw_df = df_date.resample('H').sum()

# %%
raw_df
# Out:
#                      Global_active_power  Global_reactive_power   Voltage  \
# DateTime
# 2006-12-16 17:00:00              152.024                  8.244   8447.18
# 2006-12-16 18:00:00              217.932                  4.802  14074.81
# 2006-12-16 19:00:00              204.014                  5.114  13993.95
# 2006-12-16 20:00:00              196.114                  4.506  14044.29
# 2006-12-16 21:00:00              183.388                  4.600  14229.52
# ...                                  ...                    ...       ...
# 2010-11-26 17:00:00              103.554                  3.684  14224.18
# 2010-11-26 18:00:00               94.408                  3.222  14251.91
# 2010-11-26 19:00:00               99.560                  3.602  14204.46
# 2010-11-26 20:00:00               69.822                  3.670  14363.76
# 2010-11-26 21:00:00                2.804                  0.000    719.07
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# DateTime
# 2006-12-16 17:00:00             651.6             0.0            19.0
# 2006-12-16 18:00:00             936.0             0.0           403.0
# 2006-12-16 19:00:00             870.2             0.0            86.0
# 2006-12-16 20:00:00             835.0             0.0             0.0
# 2006-12-16 21:00:00             782.8             0.0            25.0
# ...                               ...             ...             ...
# 2010-11-26 17:00:00             433.0             0.0             0.0
# 2010-11-26 18:00:00             397.2             0.0             0.0
# 2010-11-26 19:00:00             423.4             0.0             4.0
# 2010-11-26 20:00:00             294.8             0.0            64.0
# 2010-11-26 21:00:00              11.4             0.0             0.0
#
#                      Sub_metering_3
# DateTime
# 2006-12-16 17:00:00           607.0
# 2006-12-16 18:00:00          1012.0
# 2006-12-16 19:00:00          1001.0
# 2006-12-16 20:00:00          1007.0
# 2006-12-16 21:00:00          1033.0
# ...                             ...
# 2010-11-26 17:00:00           772.0
# 2010-11-26 18:00:00             0.0
# 2010-11-26 19:00:00             0.0
# 2010-11-26 20:00:00             0.0
# 2010-11-26 21:00:00             0.0
#
# [34589 rows x 7 columns]

# %% [markdown]
# # Nous n’ajusterons le modèle que sur la première année de données, puis l’évaluerons sur les 4 années de données restantes.

# %%
# prepare data for lstm
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# convert series to supervised learning
def series_to_supervised(data, n_in=7, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# load dataset
dataset = raw_df
values = dataset.values
# integer encode direction
# encoder = LabelEncoder()
# values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict

reframed.drop(reframed.columns[[8,9,10,11,12,13]], axis=1, inplace=True)
print(reframed)
# Out:
#        var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1       0.386208   0.177443   0.558893   0.382619        0.0   0.006820
# 2       0.553644   0.103358   0.931236   0.549618        0.0   0.144652
# 3       0.518286   0.110073   0.925886   0.510981        0.0   0.030869
# 4       0.498217   0.096987   0.929217   0.490311        0.0   0.000000
# 5       0.465887   0.099010   0.941472   0.459659        0.0   0.008973
# ...          ...        ...        ...        ...        ...        ...
# 34584   0.162781   0.278476   0.954569   0.162419        0.0   0.020459
# 34585   0.263073   0.079294   0.941119   0.254257        0.0   0.000000
# 34586   0.239838   0.069350   0.942953   0.233235        0.0   0.000000
# 34587   0.252927   0.077529   0.939814   0.248620        0.0   0.001436
# 34588   0.177379   0.078993   0.950354   0.173106        0.0   0.022972
#
#        var7(t-1)   var1(t)
# 1       0.469451  0.553644
# 2       0.782676  0.518286
# 3       0.774169  0.498217
# 4       0.778809  0.465887
# 5       0.798917  0.335359
# ...          ...       ...
# 34584   0.000000  0.263073
# 34585   0.597061  0.239838
# 34586   0.000000  0.252927
# 34587   0.000000  0.177379
# 34588   0.000000  0.007123
#
# [34588 rows x 8 columns]

# %%
dataset
# Out:
#                      Global_active_power  Global_reactive_power   Voltage  \
# DateTime
# 2006-12-16 17:00:00              152.024                  8.244   8447.18
# 2006-12-16 18:00:00              217.932                  4.802  14074.81
# 2006-12-16 19:00:00              204.014                  5.114  13993.95
# 2006-12-16 20:00:00              196.114                  4.506  14044.29
# 2006-12-16 21:00:00              183.388                  4.600  14229.52
# ...                                  ...                    ...       ...
# 2010-11-26 17:00:00              103.554                  3.684  14224.18
# 2010-11-26 18:00:00               94.408                  3.222  14251.91
# 2010-11-26 19:00:00               99.560                  3.602  14204.46
# 2010-11-26 20:00:00               69.822                  3.670  14363.76
# 2010-11-26 21:00:00                2.804                  0.000    719.07
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# DateTime
# 2006-12-16 17:00:00             651.6             0.0            19.0
# 2006-12-16 18:00:00             936.0             0.0           403.0
# 2006-12-16 19:00:00             870.2             0.0            86.0
# 2006-12-16 20:00:00             835.0             0.0             0.0
# 2006-12-16 21:00:00             782.8             0.0            25.0
# ...                               ...             ...             ...
# 2010-11-26 17:00:00             433.0             0.0             0.0
# 2010-11-26 18:00:00             397.2             0.0             0.0
# 2010-11-26 19:00:00             423.4             0.0             4.0
# 2010-11-26 20:00:00             294.8             0.0            64.0
# 2010-11-26 21:00:00              11.4             0.0             0.0
#
#                      Sub_metering_3
# DateTime
# 2006-12-16 17:00:00           607.0
# 2006-12-16 18:00:00          1012.0
# 2006-12-16 19:00:00          1001.0
# 2006-12-16 20:00:00          1007.0
# 2006-12-16 21:00:00          1033.0
# ...                             ...
# 2010-11-26 17:00:00           772.0
# 2010-11-26 18:00:00             0.0
# 2010-11-26 19:00:00             0.0
# 2010-11-26 20:00:00             0.0
# 2010-11-26 21:00:00             0.0
#
# [34589 rows x 7 columns]

# %% [markdown]
# L’exemple ci-dessous divise le jeu de données en trains et ensembles de tests, puis divise le train et les ensembles de tests en variables d’entrée et de sortie. Enfin, les entrées (X) sont remodelées au format 3D attendu par les LSTM, à savoir [samples, timesteps, features].
# Nous n’ajustons le modèle pour que sur la première année de données, puis l’évaluerons sur les 4 années de données restantes.

# %%
...
# split into train and test sets
values = reframed.values
n_train_hours = 365 * 24
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (8760, 1, 7) (8760,) (25828, 1, 7) (25828,)

# %% [markdown]
# L’exécution de cet exemple imprime la forme du train et teste les jeux d’entrée et de sortie avec environ 9 000 heures de données pour l’entraînement et environ 35 000 heures pour les tests.

# %%
test.shape
# Out:
# (25828, 8)

# %%
from tensorflow import keras

# design network
model = keras.Sequential()
model.add(keras.layers.LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(keras.layers.Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/50
# 274/274 - 6s - loss: 0.0876 - val_loss: 0.0678 - 6s/epoch - 22ms/step
# Epoch 2/50
# 274/274 - 2s - loss: 0.0717 - val_loss: 0.0638 - 2s/epoch - 8ms/step
# Epoch 3/50
# 274/274 - 2s - loss: 0.0674 - val_loss: 0.0605 - 2s/epoch - 8ms/step
# Epoch 4/50
# 274/274 - 2s - loss: 0.0659 - val_loss: 0.0601 - 2s/epoch - 9ms/step
# Epoch 5/50
# 274/274 - 3s - loss: 0.0656 - val_loss: 0.0597 - 3s/epoch - 11ms/step
# Epoch 6/50
# 274/274 - 3s - loss: 0.0655 - val_loss: 0.0596 - 3s/epoch - 12ms/step
# Epoch 7/50
# 274/274 - 2s - loss: 0.0655 - val_loss: 0.0597 - 2s/epoch - 8ms/step
# Epoch 8/50
# 274/274 - 3s - loss: 0.0654 - val_loss: 0.0598 - 3s/epoch - 9ms/step
# Epoch 9/50
# 274/274 - 3s - loss: 0.0652 - val_loss: 0.0595 - 3s/epoch - 11ms/step
# Epoch 10/50
# 274/274 - 3s - loss: 0.0654 - val_loss: 0.0599 - 3s/epoch - 10ms/step
# Epoch 11/50
# 274/274 - 2s - loss: 0.0652 - val_loss: 0.0595 - 2s/epoch - 9ms/step
# Epoch 12/50
# 274/274 - 2s - loss: 0.0652 - val_loss: 0.0595 - 2s/epoch - 8ms/step
# Epoch 13/50
# 274/274 - 2s - loss: 0.0651 - val_loss: 0.0594 - 2s/epoch - 9ms/step
# Epoch 14/50
# 274/274 - 2s - loss: 0.0650 - val_loss: 0.0599 - 2s/epoch - 9ms/step
# Epoch 15/50
# 274/274 - 2s - loss: 0.0652 - val_loss: 0.0594 - 2s/epoch - 9ms/step
# Epoch 16/50
# 274/274 - 2s - loss: 0.0652 - val_loss: 0.0597 - 2s/epoch - 8ms/step
# Epoch 17/50
# 274/274 - 2s - loss: 0.0650 - val_loss: 0.0598 - 2s/epoch - 8ms/step
# Epoch 18/50
# 274/274 - 2s - loss: 0.0649 - val_loss: 0.0594 - 2s/epoch - 8ms/step
# Epoch 19/50
# 274/274 - 2s - loss: 0.0648 - val_loss: 0.0596 - 2s/epoch - 9ms/step
# Epoch 20/50
# 274/274 - 2s - loss: 0.0650 - val_loss: 0.0596 - 2s/epoch - 8ms/step
# Epoch 21/50
# 274/274 - 2s - loss: 0.0649 - val_loss: 0.0595 - 2s/epoch - 8ms/step
# Epoch 22/50
# 274/274 - 2s - loss: 0.0648 - val_loss: 0.0596 - 2s/epoch - 8ms/step
# Epoch 23/50
# 274/274 - 2s - loss: 0.0648 - val_loss: 0.0596 - 2s/epoch - 8ms/step
# Epoch 24/50
# 274/274 - 2s - loss: 0.0647 - val_loss: 0.0597 - 2s/epoch - 9ms/step
# Epoch 25/50
# 274/274 - 2s - loss: 0.0649 - val_loss: 0.0595 - 2s/epoch - 8ms/step
# Epoch 26/50
# 274/274 - 2s - loss: 0.0646 - val_loss: 0.0597 - 2s/epoch - 8ms/step
# Epoch 27/50
# 274/274 - 2s - loss: 0.0649 - val_loss: 0.0594 - 2s/epoch - 8ms/step
# Epoch 28/50
# 274/274 - 2s - loss: 0.0648 - val_loss: 0.0596 - 2s/epoch - 8ms/step
# Epoch 29/50
# 274/274 - 2s - loss: 0.0648 - val_loss: 0.0596 - 2s/epoch - 8ms/step
# Epoch 30/50
# 274/274 - 2s - loss: 0.0647 - val_loss: 0.0596 - 2s/epoch - 8ms/step
# Epoch 31/50
# 274/274 - 2s - loss: 0.0647 - val_loss: 0.0598 - 2s/epoch - 8ms/step
# Epoch 32/50
# 274/274 - 2s - loss: 0.0647 - val_loss: 0.0596 - 2s/epoch - 8ms/step
# Epoch 33/50
# 274/274 - 2s - loss: 0.0646 - val_loss: 0.0598 - 2s/epoch - 8ms/step
# Epoch 34/50
# 274/274 - 2s - loss: 0.0647 - val_loss: 0.0596 - 2s/epoch - 8ms/step
# Epoch 35/50
# 274/274 - 2s - loss: 0.0646 - val_loss: 0.0597 - 2s/epoch - 8ms/step
# Epoch 36/50
# 274/274 - 2s - loss: 0.0646 - val_loss: 0.0597 - 2s/epoch - 8ms/step
# Epoch 37/50
# 274/274 - 3s - loss: 0.0646 - val_loss: 0.0597 - 3s/epoch - 12ms/step
# Epoch 38/50
# 274/274 - 2s - loss: 0.0645 - val_loss: 0.0598 - 2s/epoch - 8ms/step
# Epoch 39/50
# 274/274 - 2s - loss: 0.0645 - val_loss: 0.0600 - 2s/epoch - 8ms/step
# Epoch 40/50
# 274/274 - 2s - loss: 0.0646 - val_loss: 0.0599 - 2s/epoch - 8ms/step
# Epoch 41/50
# 274/274 - 2s - loss: 0.0646 - val_loss: 0.0600 - 2s/epoch - 8ms/step
# Epoch 42/50
# 274/274 - 2s - loss: 0.0646 - val_loss: 0.0600 - 2s/epoch - 8ms/step
# Epoch 43/50
# 274/274 - 2s - loss: 0.0645 - val_loss: 0.0601 - 2s/epoch - 8ms/step
# Epoch 44/50
# 274/274 - 2s - loss: 0.0645 - val_loss: 0.0600 - 2s/epoch - 8ms/step
# Epoch 45/50
# 274/274 - 2s - loss: 0.0644 - val_loss: 0.0603 - 2s/epoch - 8ms/step
# Epoch 46/50
# 274/274 - 2s - loss: 0.0646 - val_loss: 0.0602 - 2s/epoch - 8ms/step
# Epoch 47/50
# 274/274 - 2s - loss: 0.0645 - val_loss: 0.0603 - 2s/epoch - 8ms/step
# Epoch 48/50
# 274/274 - 2s - loss: 0.0645 - val_loss: 0.0605 - 2s/epoch - 8ms/step
# Epoch 49/50
# 274/274 - 2s - loss: 0.0644 - val_loss: 0.0604 - 2s/epoch - 8ms/step
# Epoch 50/50
# 274/274 - 2s - loss: 0.0644 - val_loss: 0.0604 - 2s/epoch - 8ms/step

# %%
test_X
# Out:
# array([[[0.37725085, 0.08458889, 0.9460147 , ..., 0.        ,
#          0.00897344, 0.80897135]],
#
#        [[0.40036893, 0.05484288, 0.94340587, ..., 0.        ,
#          0.        , 0.804331  ]],
#
#        [[0.43200758, 0.27804562, 0.945312  , ..., 0.        ,
#          0.0086145 , 0.80742455]],
#
#        ...,
#
#        [[0.23983823, 0.06934997, 0.94295335, ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[0.2529266 , 0.07752906, 0.93981385, ..., 0.        ,
#          0.00143575, 0.        ]],
#
#        [[0.17737888, 0.07899268, 0.9503537 , ..., 0.        ,
#          0.022972  , 0.        ]]], dtype=float32)

# %%
from numpy import concatenate
from math import sqrt
from sklearn.metrics import mean_squared_error

# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# %%
yhat.shape
# Out:
# (25828, 1)

# %%
test_X[:, 1:].shape
# Out:
# (25828, 6)

# %%
# invert scaling for forecast
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
r2 = sqrt(r2_score(inv_y, inv_yhat))
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
explained_variance_score = sqrt(explained_variance_score(inv_y, inv_yhat))
print('Test MSE: %.3f' % rmse)
print('Test R2: %.3f' % r2)
print('Test explained_variance_score: %.3f' % explained_variance_score)
# Out:
# Test MSE: 36.539
# Test R2: 0.707
# Test explained_variance_score: 0.716

# %%
yhat
# Out:
# array([[0.34564328],
#        [0.35946706],
#        [0.41678274],
#        ...,
#        [0.2664363 ],
#        [0.28065684],
#        [0.20093006]], dtype=float32)

# %%
# ax = plot(alpha=0.5, title="Average Sales")
plt.plot(inv_yhat,label="Forecast", color='C3')
# ax.legend();

# %%
plt.plot(inv_y,label="test", color='C0')

# %% [markdown]
# Nous n’ajustons le modèle pour que sur les deuw premières années de données, puis l’évaluerons sur les 2 années de données restantes.

# %%
# prepare data for lstm
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# convert series to supervised learning
def series_to_supervised(data, n_in=7, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# load dataset
dataset2 = raw_df
values2 = dataset2.values
# integer encode direction
# encoder = LabelEncoder()
# values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values2 = values2.astype('float32')
# normalize features
scaler2 = MinMaxScaler(feature_range=(0, 1))
scaled = scaler2.fit_transform(values2)
# frame as supervised learning
reframed2 = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict

reframed2.drop(reframed2.columns[[8,9,10,11,12,13]], axis=1, inplace=True)
print(reframed2.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.386208   0.177443   0.558893   0.382619        0.0   0.006820
# 2   0.553644   0.103358   0.931236   0.549618        0.0   0.144652
# 3   0.518286   0.110073   0.925886   0.510981        0.0   0.030869
# 4   0.498217   0.096987   0.929217   0.490311        0.0   0.000000
# 5   0.465887   0.099010   0.941472   0.459659        0.0   0.008973
#
#    var7(t-1)   var1(t)
# 1   0.469451  0.553644
# 2   0.782676  0.518286
# 3   0.774169  0.498217
# 4   0.778809  0.465887
# 5   0.798917  0.335359

# %%
reframed2.values
# Out:
# array([[0.38620847, 0.17744297, 0.55889326, ..., 0.00681981, 0.46945086,
#         0.55364406],
#        [0.55364406, 0.10335772, 0.9312358 , ..., 0.14465183, 0.7826759 ,
#         0.51828617],
#        [0.51828617, 0.11007318, 0.92588586, ..., 0.03086863, 0.77416855,
#         0.49821663],
#        ...,
#        [0.23983823, 0.06934997, 0.94295335, ..., 0.        , 0.        ,
#         0.2529266 ],
#        [0.2529266 , 0.07752906, 0.93981385, ..., 0.00143575, 0.        ,
#         0.17737888],
#        [0.17737888, 0.07899268, 0.9503537 , ..., 0.022972  , 0.        ,
#         0.0071234 ]], dtype=float32)

# %%
...
# split into train2 and test2 sets
values2 = reframed2.values
n_train_hours2 = 365 * 24
train2 = values[n_train_hours2:, :]
test2 = values[:n_train_hours2, :]
# split into input and outputs
train2_X, train2_y = train2[:, :-1], train2[:, -1]
test2_X, test2_y = test2[:, :-1], test2[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train2_X = train2_X.reshape((train2_X.shape[0], 1, train2_X.shape[1]))
test2_X = test2_X.reshape((test2_X.shape[0], 1, test2_X.shape[1]))
print(train2_X.shape, train2_y.shape, test2_X.shape, test2_y.shape)
# Out:
# (25828, 1, 7) (25828,) (8760, 1, 7) (8760,)

# %%
test2.shape
# Out:
# (8760, 8)

# %%
train2_X
# Out:
# array([[[0.37725085, 0.08458889, 0.9460147 , ..., 0.        ,
#          0.00897344, 0.80897135]],
#
#        [[0.40036893, 0.05484288, 0.94340587, ..., 0.        ,
#          0.        , 0.804331  ]],
#
#        [[0.43200758, 0.27804562, 0.945312  , ..., 0.        ,
#          0.0086145 , 0.80742455]],
#
#        ...,
#
#        [[0.23983823, 0.06934997, 0.94295335, ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[0.2529266 , 0.07752906, 0.93981385, ..., 0.        ,
#          0.00143575, 0.        ]],
#
#        [[0.17737888, 0.07899268, 0.9503537 , ..., 0.        ,
#          0.022972  , 0.        ]]], dtype=float32)

# %%
from tensorflow import keras

# design network
model2 = keras.Sequential()
model2.add(keras.layers.LSTM(50, input_shape=(train2_X.shape[1], train2_X.shape[2])))
model2.add(keras.layers.Dense(1))
model2.compile(loss='mae', optimizer='adam')
# fit network
history2 = model2.fit(train2_X, train2_y, epochs=50, batch_size=32, validation_data=(test2_X, test2_y), verbose=2, shuffle=False)
# plot history

pyplot.show()
# Out:
# Epoch 1/50
# 808/808 - 6s - loss: 0.0649 - val_loss: 0.0683 - 6s/epoch - 7ms/step
# Epoch 2/50
# 808/808 - 3s - loss: 0.0600 - val_loss: 0.0660 - 3s/epoch - 3ms/step
# Epoch 3/50
# 808/808 - 3s - loss: 0.0596 - val_loss: 0.0657 - 3s/epoch - 3ms/step
# Epoch 4/50
# 808/808 - 3s - loss: 0.0594 - val_loss: 0.0654 - 3s/epoch - 3ms/step
# Epoch 5/50
# 808/808 - 3s - loss: 0.0592 - val_loss: 0.0651 - 3s/epoch - 3ms/step
# Epoch 6/50
# 808/808 - 2s - loss: 0.0591 - val_loss: 0.0654 - 2s/epoch - 3ms/step
# Epoch 7/50
# 808/808 - 4s - loss: 0.0590 - val_loss: 0.0653 - 4s/epoch - 5ms/step
# Epoch 8/50
# 808/808 - 4s - loss: 0.0589 - val_loss: 0.0654 - 4s/epoch - 5ms/step
# Epoch 9/50
# 808/808 - 3s - loss: 0.0589 - val_loss: 0.0653 - 3s/epoch - 4ms/step
# Epoch 10/50
# 808/808 - 3s - loss: 0.0588 - val_loss: 0.0656 - 3s/epoch - 3ms/step
# Epoch 11/50
# 808/808 - 3s - loss: 0.0588 - val_loss: 0.0659 - 3s/epoch - 3ms/step
# Epoch 12/50
# 808/808 - 3s - loss: 0.0587 - val_loss: 0.0651 - 3s/epoch - 3ms/step
# Epoch 13/50
# 808/808 - 3s - loss: 0.0588 - val_loss: 0.0664 - 3s/epoch - 3ms/step
# Epoch 14/50
# 808/808 - 3s - loss: 0.0587 - val_loss: 0.0662 - 3s/epoch - 3ms/step
# Epoch 15/50
# 808/808 - 3s - loss: 0.0588 - val_loss: 0.0666 - 3s/epoch - 3ms/step
# Epoch 16/50
# 808/808 - 3s - loss: 0.0587 - val_loss: 0.0665 - 3s/epoch - 3ms/step
# Epoch 17/50
# 808/808 - 3s - loss: 0.0586 - val_loss: 0.0668 - 3s/epoch - 3ms/step
# Epoch 18/50
# 808/808 - 3s - loss: 0.0587 - val_loss: 0.0669 - 3s/epoch - 3ms/step
# Epoch 19/50
# 808/808 - 3s - loss: 0.0586 - val_loss: 0.0669 - 3s/epoch - 3ms/step
# Epoch 20/50
# 808/808 - 3s - loss: 0.0586 - val_loss: 0.0659 - 3s/epoch - 3ms/step
# Epoch 21/50
# 808/808 - 3s - loss: 0.0586 - val_loss: 0.0670 - 3s/epoch - 4ms/step
# Epoch 22/50
# 808/808 - 3s - loss: 0.0586 - val_loss: 0.0663 - 3s/epoch - 4ms/step
# Epoch 23/50
# 808/808 - 4s - loss: 0.0586 - val_loss: 0.0667 - 4s/epoch - 5ms/step
# Epoch 24/50
# 808/808 - 4s - loss: 0.0585 - val_loss: 0.0664 - 4s/epoch - 5ms/step
# Epoch 25/50
# 808/808 - 2s - loss: 0.0585 - val_loss: 0.0665 - 2s/epoch - 3ms/step
# Epoch 26/50
# 808/808 - 2s - loss: 0.0585 - val_loss: 0.0666 - 2s/epoch - 3ms/step
# Epoch 27/50
# 808/808 - 3s - loss: 0.0586 - val_loss: 0.0674 - 3s/epoch - 3ms/step
# Epoch 28/50
# 808/808 - 2s - loss: 0.0585 - val_loss: 0.0674 - 2s/epoch - 3ms/step
# Epoch 29/50
# 808/808 - 2s - loss: 0.0586 - val_loss: 0.0672 - 2s/epoch - 3ms/step
# Epoch 30/50
# 808/808 - 3s - loss: 0.0585 - val_loss: 0.0674 - 3s/epoch - 3ms/step
# Epoch 31/50
# 808/808 - 3s - loss: 0.0585 - val_loss: 0.0674 - 3s/epoch - 4ms/step
# Epoch 32/50
# 808/808 - 3s - loss: 0.0585 - val_loss: 0.0674 - 3s/epoch - 3ms/step
# Epoch 33/50
# 808/808 - 3s - loss: 0.0585 - val_loss: 0.0673 - 3s/epoch - 3ms/step
# Epoch 34/50
# 808/808 - 3s - loss: 0.0584 - val_loss: 0.0667 - 3s/epoch - 4ms/step
# Epoch 35/50
# 808/808 - 3s - loss: 0.0584 - val_loss: 0.0673 - 3s/epoch - 3ms/step
# Epoch 36/50
# 808/808 - 3s - loss: 0.0585 - val_loss: 0.0673 - 3s/epoch - 3ms/step
# Epoch 37/50
# 808/808 - 4s - loss: 0.0585 - val_loss: 0.0675 - 4s/epoch - 5ms/step
# Epoch 38/50
# 808/808 - 4s - loss: 0.0585 - val_loss: 0.0675 - 4s/epoch - 4ms/step
# Epoch 39/50
# 808/808 - 3s - loss: 0.0585 - val_loss: 0.0675 - 3s/epoch - 4ms/step
# Epoch 40/50
# 808/808 - 3s - loss: 0.0584 - val_loss: 0.0675 - 3s/epoch - 3ms/step
# Epoch 41/50
# 808/808 - 2s - loss: 0.0585 - val_loss: 0.0676 - 2s/epoch - 3ms/step
# Epoch 42/50
# 808/808 - 3s - loss: 0.0584 - val_loss: 0.0676 - 3s/epoch - 3ms/step
# Epoch 43/50
# 808/808 - 3s - loss: 0.0584 - val_loss: 0.0676 - 3s/epoch - 3ms/step
# Epoch 44/50
# 808/808 - 3s - loss: 0.0584 - val_loss: 0.0676 - 3s/epoch - 3ms/step
# Epoch 45/50
# 808/808 - 2s - loss: 0.0584 - val_loss: 0.0676 - 2s/epoch - 3ms/step
# Epoch 46/50
# 808/808 - 2s - loss: 0.0584 - val_loss: 0.0677 - 2s/epoch - 3ms/step
# Epoch 47/50
# 808/808 - 3s - loss: 0.0584 - val_loss: 0.0677 - 3s/epoch - 3ms/step
# Epoch 48/50
# 808/808 - 3s - loss: 0.0584 - val_loss: 0.0675 - 3s/epoch - 4ms/step
# Epoch 49/50
# 808/808 - 3s - loss: 0.0584 - val_loss: 0.0675 - 3s/epoch - 4ms/step
# Epoch 50/50
# 808/808 - 3s - loss: 0.0584 - val_loss: 0.0672 - 3s/epoch - 4ms/step

# %%
pyplot.plot(history2.history['loss'], label='train')
pyplot.plot(history2.history['val_loss'], label='test')
pyplot.legend()

# %%
test2_X
# Out:
# array([[[0.38620847, 0.17744297, 0.55889326, ..., 0.        ,
#          0.00681981, 0.46945086]],
#
#        [[0.55364406, 0.10335772, 0.9312358 , ..., 0.        ,
#          0.14465183, 0.7826759 ]],
#
#        [[0.51828617, 0.11007318, 0.92588586, ..., 0.        ,
#          0.03086863, 0.77416855]],
#
#        ...,
#
#        [[0.37603652, 0.1242359 , 0.96875435, ..., 0.00206754,
#          0.01758794, 0.8476411 ]],
#
#        [[0.3721598 , 0.12165303, 0.97189575, ..., 0.28807718,
#          0.00717875, 0.8530549 ]],
#
#        [[0.24920739, 0.05923375, 0.96845865, ..., 0.        ,
#          0.        , 0.84686774]]], dtype=float32)

# %%
from numpy import concatenate
from math import sqrt
from sklearn.metrics import mean_squared_error

# make a prediction
print(test2_X.shape)
yhat2 = model2.predict(test2_X)
print(yhat2.shape)
test2_X = test2_X.reshape((test2_X.shape[0], test2_X.shape[2]))
# Out:
# (8760, 1, 7)
# (8760, 1)

# %%
yhat2.shape
# Out:
# (8760, 1)

# %%
test2_X[:, 1:].shape
# Out:
# (8760, 6)

# %%
# invert scaling for forecast
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
inv_yhat2 = concatenate((yhat2, test2_X[:, 1:]), axis=1)
inv_yhat2 = scaler.inverse_transform(inv_yhat2)
inv_yhat2 = inv_yhat2[:,0]
# invert scaling for actual
test2_y = test2_y.reshape((len(test2_y), 1))
inv_y2 = concatenate((test2_y, test2_X[:, 1:]), axis=1)
inv_y2 = scaler.inverse_transform(inv_y2)
inv_y2 = inv_y2[:,0]
# calculate RMSE
r2 = sqrt(r2_score(inv_y2, inv_yhat2))
rmse = sqrt(mean_squared_error(inv_y2, inv_yhat2))
explained_variance_score = sqrt(explained_variance_score(inv_y2, inv_yhat2))
print('Test MSE: %.3f' % rmse)
print('Test R2: %.3f' % r2)
print('Test explained_variance_score: %.3f' % explained_variance_score)
# Out:
# Test MSE: 39.622
# Test R2: 0.754
# Test explained_variance_score: 0.759

# %%
plt.plot(inv_yhat2)

# %%
plt.plot(inv_y2)

# %%
yhat
# Out:
# array([[0.34564328],
#        [0.35946706],
#        [0.41678274],
#        ...,
#        [0.2664363 ],
#        [0.28065684],
#        [0.20093006]], dtype=float32)

# %%
# ax = plot(alpha=0.5, title="Average Sales")
plt.figure(figsize=(64, 20))


plt.plot(yhat2,label="Forecast", color='C3')
plt.show()
# ax.legend();

# %%
plt.plot(test2_y,label="test", color='C0')

# %%
reframed2
# Out:
#        var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1       0.386208   0.177443   0.558893   0.382619        0.0   0.006820
# 2       0.553644   0.103358   0.931236   0.549618        0.0   0.144652
# 3       0.518286   0.110073   0.925886   0.510981        0.0   0.030869
# 4       0.498217   0.096987   0.929217   0.490311        0.0   0.000000
# 5       0.465887   0.099010   0.941472   0.459659        0.0   0.008973
# ...          ...        ...        ...        ...        ...        ...
# 34584   0.162781   0.278476   0.954569   0.162419        0.0   0.020459
# 34585   0.263073   0.079294   0.941119   0.254257        0.0   0.000000
# 34586   0.239838   0.069350   0.942953   0.233235        0.0   0.000000
# 34587   0.252927   0.077529   0.939814   0.248620        0.0   0.001436
# 34588   0.177379   0.078993   0.950354   0.173106        0.0   0.022972
#
#        var7(t-1)   var1(t)
# 1       0.469451  0.553644
# 2       0.782676  0.518286
# 3       0.774169  0.498217
# 4       0.778809  0.465887
# 5       0.798917  0.335359
# ...          ...       ...
# 34584   0.000000  0.263073
# 34585   0.597061  0.239838
# 34586   0.000000  0.252927
# 34587   0.000000  0.177379
# 34588   0.000000  0.007123
#
# [34588 rows x 8 columns]
